# %%
marks = 80

if marks >= 35:
    print("Pass")
# Out:
# Pass

# %%
marks = 20

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
password = "python"

if password == "python":
    print("Login Successful")
else:
    print("Wrong Password")
# Out:
# Login Successful

# %%
marks = 75

if marks >= 90:
    print("Grade A")

elif marks >= 75:
    print("Grade B")

elif marks >= 50:
    print("Grade C")

else:
    print("Fail")
# Out:
# Grade B

# %%
age = 25
citizen = True

if age >= 18:
    if citizen:
        print("Eligible to Vote")
# Out:
# Eligible to Vote

# %%
if marks >= 90:
    print("A")

elif marks >= 75:
    print("B")
print(marks)
# Out:
# B
# 75
